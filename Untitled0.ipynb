# %% [markdown]
# <a href="https://colab.research.google.com/github/simaofficial112-sketch/class_demo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s= "python"
print(s[:2])
print(s[0:5:2])
print(s[::-1])
# Out:
# py
# pto
# nohtyp

# %%
name = "python"
programming = "programming"
print(name + programming, sep = "+")
# Out:
# pythonprogramming

# %%
a = "*"
print(a)
print(a * 6, end = "+")
print(4 * 4)
# Out:
# *
# ******+16

# %%
name = "python programming"
print(name)
print(name.lower())
print(name. title())
print(name.find("pro"))
print(name.find("test"))
print(name.count("m"))
print(name.startswith("py"))
print(name.endswith("ing"))
age = "22"
print(age.isdigit())
print(name.isalpha())
print(age.isalnum())
# Out:
# python programming
# python programming
# Python Programming
# 7
# -1
# 2
# True
# True
# True
# False
# True

# %%
name = "my name is simanchala  "
print(name)
print(name.strip())
print(name.lstrip())
print(name.rstrip())
print(name.replace("name", "age"))
print(name.split(","))
print(name.split())

name2="appele is , a fruit and banna is a fruit , fruit is good for health"
# Out:
# my name is simanchala
# my name is simanchala
# my name is simanchala
# my name is simanchala
# my age is simanchala
# ['my name is simanchala  ']
# ['my', 'name', 'is', 'simanchala']

# %%
text= "python"
print(text.center(20, "-"))
print(text.ljust(20, "-"))
print(text.rjust(10,"0"))
print(text.zfill())
# Out:
# -------python-------
# python--------------
# 0000python
